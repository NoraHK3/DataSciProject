# %% [markdown]
# <a href="https://colab.research.google.com/github/NoraHK3/DataSciProject/blob/main/fufu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fufu's Kitchen - Middle Eastern category scraper (Colab-ready)
# Outputs: fufus_middle_eastern.json and fufus_middle_eastern.csv
# Fields: dish_name, labels (main ingredients), image_file, date_scraped

import requests, re, time, json, pandas as pd, os
from bs4 import BeautifulSoup
from datetime import datetime

BASE_CATEGORY = "https://www.fufuskitchen.com/category/middle-eastern/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}
REQUEST_TIMEOUT = 25
CRAWL_DELAY_SEC = 0.6   # Be polite to the site
SAVE_EVERY = 30

# Folder for images
IMG_DIR = "images"
os.makedirs(IMG_DIR, exist_ok=True)

# Vocabulary to collapse free-text ingredients into concise "main" labels
INGREDIENT_VOCAB = {
    "rice","bulgur","couscous","vermicelli","bread","pita","khubz","freekeh",
    "chicken","beef","lamb","mutton","fish","shrimp","prawn","egg","eggs","turkey",
    "chickpeas","lentils","fava","beans","tomato","tomatoes","onion","onions","garlic","ginger",
    "eggplant","zucchini","okra","spinach","parsley","cilantro","coriander","mint",
    "potato","potatoes","pepper","bell pepper","green chili",
    "yogurt","labneh","laban","cream","butter","ghee","olive oil","oil","tahini","milk",
    "tomato paste","tomato sauce","pomegranate molasses","harissa",
    "cumin","coriander powder","turmeric","cardamom","cinnamon","cloves","sumac","zaatar","allspice",
    "black pepper","paprika","chili","bay leaf","bay leaves","saffron","nutmeg",
    "lemon","lime","vinegar","salt","water","garlic powder","onion powder"
}

def get_soup(url):
    r = requests.get(url, headers=HEADERS, timeout=REQUEST_TIMEOUT)
    r.raise_for_status()
    return BeautifulSoup(r.text, "html.parser")

def find_category_pages(first_url):
    pages = []
    page_num = 1
    while True:
        url = first_url if page_num == 1 else first_url.rstrip('/') + f"/page/{page_num}/"
        try:
            soup = get_soup(url)
        except Exception:
            break
        posts = extract_post_links_from_category(soup)
        if not posts:
            break
        pages.append((url, posts))
        page_num += 1
        time.sleep(CRAWL_DELAY_SEC)
    return pages

def extract_post_links_from_category(soup):
    links = set()
    for a in soup.select("article h2 a, h2.entry-title a, .entry-title a, a[rel='bookmark']"):
        href = a.get("href")
        if href and href.startswith("https://www.fufuskitchen.com/"):
            links.add(href)
    if not links:
        for a in soup.select("a[href*='fufuskitchen.com/']"):
            href = a.get("href")
            if href and "/category/" not in href and "/page/" not in href:
                links.add(href)
    return sorted(links)

def detect_ingredients_blocks(soup):
    blocks = []
    wprm_items = soup.select(".wprm-recipe-ingredient, .wprm-recipe-ingredient-name")
    if wprm_items:
        for el in wprm_items:
            txt = el.get_text(" ", strip=True)
            if txt:
                blocks.append(txt)
    if not blocks:
        hdr = soup.find(lambda t: t and t.name in ("h2","h3","h4") and "ingredient" in t.get_text(strip=True).lower())
        if hdr:
            ul = hdr.find_next(["ul","ol"])
            if ul:
                for li in ul.find_all("li"):
                    txt = re.sub(r"\s+", " ", li.get_text(" ", strip=True))
                    if txt:
                        blocks.append(txt)
    if not blocks:
        for script in soup.find_all("script", type="application/ld+json"):
            try:
                data = json.loads(script.string)
            except Exception:
                continue
            def _extract_from_obj(obj):
                nonlocal blocks
                if isinstance(obj, dict):
                    if obj.get("@type") == "Recipe" and obj.get("recipeIngredient"):
                        for it in obj["recipeIngredient"]:
                            if isinstance(it, str) and it.strip():
                                blocks.append(it.strip())
                elif isinstance(obj, list):
                    for o in obj:
                        _extract_from_obj(o)
            _extract_from_obj(data)
    cleaned = []
    for line in blocks:
        line = re.sub(r"\s+", " ", line).strip()
        if line:
            cleaned.append(line)
    return cleaned

def normalize_labels(ingredients_list):
    labels = set()
    for line in ingredients_list:
        low = line.lower()
        for token in sorted(INGREDIENT_VOCAB, key=lambda x: -len(x)):
            if token in low:
                normalized = (token
                              .replace("tomatoes","tomato")
                              .replace("onions","onion")
                              .replace("potatoes","potato")
                              .replace("eggs","egg")
                              .replace("bay leaves","bay leaf")
                              .replace("prawns","shrimp"))
                labels.add(normalized)
    if "coriander powder" in labels and "coriander" in labels:
        labels.discard("coriander")
    return sorted(labels)

def extract_title(soup):
    rname = soup.select_one(".wprm-recipe-name")
    if rname:
        return rname.get_text(strip=True)
    h1 = soup.find("h1")
    if h1:
        return h1.get_text(strip=True)
    t = soup.find("title")
    return t.get_text(strip=True) if t else ""

def extract_image_url(soup):
    og = soup.find("meta", property="og:image")
    if og and og.get("content"):
        return og["content"]
    img = soup.select_one(".wprm-recipe img, article img")
    if img and img.get("src"):
        return img["src"]
    img = soup.find("img")
    return img["src"] if img and img.get("src") else ""

def download_image(url, dish_name):
    if not url:
        return ""
    try:
        r = requests.get(url, headers=HEADERS, timeout=REQUEST_TIMEOUT, stream=True)
        r.raise_for_status()
        base = re.sub(r"[^\w\-]+", "_", dish_name.lower())[:50]
        ext = os.path.splitext(url)[1].split("?")[0] or ".jpg"
        fname = f"{base}{ext}"
        path = os.path.join(IMG_DIR, fname)
        with open(path, "wb") as f:
            for chunk in r.iter_content(1024):
                f.write(chunk)
        return path
    except Exception:
        return ""

def scrape_recipe(url):
    soup = get_soup(url)
    dish_name = extract_title(soup)
    ing_lines = detect_ingredients_blocks(soup)
    labels = normalize_labels(ing_lines)
    image_url = extract_image_url(soup)
    image_file = download_image(image_url, dish_name)
    return {
        "dish_name": dish_name,
        "labels": labels,
        "image_url": image_url,
        "date_scraped": datetime.utcnow().date().isoformat()
    }

def checkpoint(rows, json_name="fufus_middle_eastern.json", csv_name="fufus_middle_eastern.csv"):
    with open(json_name, "w", encoding="utf-8") as f:
        json.dump(rows, f, ensure_ascii=False, indent=2)
    df = pd.DataFrame(rows)
    if not df.empty:
        df["labels"] = df["labels"].apply(lambda xs: ";".join(xs))
    df.to_csv(csv_name, index=False, encoding="utf-8-sig")

def main():
    pages = find_category_pages(BASE_CATEGORY)
    print(f"Found {len(pages)} category pages.")
    all_links = []
    for url, links in pages:
        print(f"- {url} -> {len(links)} posts")
        all_links.extend(links)

    seen, post_links = set(), []
    for u in all_links:
        if u not in seen:
            seen.add(u)
            post_links.append(u)
    print(f"Unique posts: {len(post_links)}")

    results = []
    for idx, url in enumerate(post_links, 1):
        try:
            item = scrape_recipe(url)
            if item["dish_name"] and item["labels"]:
                results.append(item)
                print(f"[{idx}/{len(post_links)}] {item['dish_name']}  (labels: {', '.join(item['labels'])})")
            else:
                print(f"[{idx}/{len(post_links)}] Skipped: {url}")
        except Exception as e:
            print(f"[{idx}/{len(post_links)}] Error: {url} -> {e}")
        time.sleep(CRAWL_DELAY_SEC)

        if idx % SAVE_EVERY == 0:
            checkpoint(results)
            print(f"Checkpoint saved at {idx} recipes...")

    checkpoint(results)
    print(f"Done. Saved {len(results)} recipes.")

if __name__ == "__main__":
    main()
# Out:
# Found 8 category pages.
# - https://www.fufuskitchen.com/category/middle-eastern/ -> 18 posts
# - https://www.fufuskitchen.com/category/middle-eastern/page/2/ -> 18 posts
# - https://www.fufuskitchen.com/category/middle-eastern/page/3/ -> 18 posts
# - https://www.fufuskitchen.com/category/middle-eastern/page/4/ -> 18 posts
# - https://www.fufuskitchen.com/category/middle-eastern/page/5/ -> 18 posts
# - https://www.fufuskitchen.com/category/middle-eastern/page/6/ -> 18 posts
# - https://www.fufuskitchen.com/category/middle-eastern/page/7/ -> 18 posts
# - https://www.fufuskitchen.com/category/middle-eastern/page/8/ -> 7 posts
# Unique posts: 133
# /tmp/ipython-input-60781590.py:179: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "date_scraped": datetime.utcnow().date().isoformat()
# [1/133] Baba Ghanoush (Roasted Eggplant Dip)  (labels: cloves, cumin, egg, eggplant, garlic, lemon, oil, olive oil, paprika, salt, tahini)
# [2/133] Baked Lamb and Vegetables  (labels: allspice, bell pepper, black pepper, cloves, garlic, lamb, oil, olive oil, onion, pepper, salt, tomato, tomato paste, zucchini)
# [3/133] Braised Chuck Roast  (labels: bay leaf, black pepper, cardamom, chili, cinnamon, cloves, garlic, garlic powder, oil, onion, onion powder, paprika, pepper, salt, tomato, tomato paste, turmeric)
# [4/133] Date Stuffed Bread (Ma’arouk)  (labels: butter, cardamom, cinnamon, cream, egg, ghee, milk, salt)
# [5/133] Easy Authentic Hummus Recipe  (labels: cloves, cumin, garlic, lemon, oil, olive oil, parsley, salt, sumac, tahini)
# [6/133] Easy Labneh Dip Recipe  (labels: chili, cloves, garlic, labneh, lemon, oil, olive oil, pepper, salt)
# [7/133] Herby Potato Salad  (labels: cilantro, cloves, garlic, lemon, mint, oil, olive oil, onion, parsley, potato, salt)
# [8/133] Jaj Mahshi (Rice Stuffed Chicken)  (labels: beef, chicken, garlic, garlic powder, ghee, lemon, oil, olive oil, onion, paprika, pepper, rice, salt, turmeric, water)
# [9/133] Lamb Tagine  (labels: black pepper, cardamom, chili, cilantro, cinnamon, cloves, coriander, cumin, egg, garlic, garlic powder, ginger, lamb, mint, onion, paprika, pepper, potato, salt, turmeric)
# [10/133] Maamoul  (labels: butter, cinnamon, milk, salt, water)
# [11/133] Mansaf  (labels: bay leaf, bread, cardamom, ghee, lamb, lemon, oil, olive oil, onion, parsley, rice, salt, turmeric, water, yogurt)
# [12/133] Molokhia  (labels: bay leaf, chicken, cloves, coriander, garlic, garlic powder, lemon, oil, olive oil, onion, paprika, pepper, salt)
# [13/133] Musakhan Rolls  (labels: bay leaf, bread, chicken, cloves, garlic, lemon, oil, olive oil, onion, pepper, salt, sumac)
# [14/133] No Bake Dubai Chocolate Cake  (labels: butter, cream, oil, salt, water)
# [15/133] Ouzi  (labels: bay leaf, cardamom, lamb, lemon, lime, oil, olive oil, onion, paprika, parsley, pepper, rice, salt, water)
# [16/133] Palestinian Date Ring Cookies  (labels: butter, cinnamon, milk, oil, olive oil, water)
# [17/133] Taboon Bread (Palestinian Flatbread)  (labels: milk, oil, olive oil, salt, water)
# [18/133] Za’atar Buns  (labels: cream, egg, milk, oil, olive oil, salt, vinegar, water)
# [19/133] Almond Coffee Cake  (labels: butter, cinnamon, egg, salt)
# [20/133] Fattoush Salad  (labels: bell pepper, bread, lemon, mint, oil, olive oil, onion, parsley, pepper, pita, pomegranate molasses, salt, sumac, tomato, vinegar)
# [21/133] Baked Kofta Kebab  (labels: allspice, beef, bell pepper, black pepper, cloves, garlic, garlic powder, onion, paprika, parsley, pepper, salt, tomato, tomato paste)
# [22/133] Basbousa (Middle Eastern Semolina Cake)  (labels: butter, lemon, milk, salt, tahini, water, yogurt)
# [23/133] Beef Sambousek  (labels: beef, cloves, cream, egg, garlic, oil, olive oil, onion, parsley, pepper, pomegranate molasses, salt, tomato, tomato paste)
# [24/133] Chicken Shawarma Bowl  (labels: black pepper, chicken, chili, cinnamon, cumin, garlic, garlic powder, lemon, mint, oil, olive oil, onion, paprika, pepper, potato, rice, salt, tahini, tomato, turmeric, water)
# [25/133] Chipotle Chicken Bowl (Copycat Recipe)  (labels: bell pepper, black pepper, chicken, chili, cilantro, cloves, cumin, garlic, garlic powder, lime, oil, olive oil, onion, onion powder, paprika, pepper, rice, salt, tomato, vinegar, water)
# [26/133] Cucumber Yogurt Salad (Khyar bi Laban)  (labels: garlic, lemon, mint, oil, olive oil, salt, yogurt)
# [27/133] Date Scones  (labels: butter, cinnamon, cream, salt)
# [28/133] Eggplant Fatteh  (labels: black pepper, cloves, egg, eggplant, garlic, garlic powder, ghee, lemon, oil, olive oil, parsley, pepper, pita, salt, tahini, yogurt)
# [29/133] Freekeh Soup  (labels: black pepper, chicken, freekeh, oil, olive oil, onion, pepper, salt, water)
# [30/133] Halal Cart Chicken  (labels: bay leaf, black pepper, chicken, cloves, coriander, cream, cumin, garlic, garlic powder, ghee, lemon, oil, olive oil, paprika, pepper, pita, rice, salt, tomato, turmeric, vinegar, water, yogurt)
# Checkpoint saved at 30 recipes...
# [31/133] Maqluba with Lamb  (labels: allspice, bay leaf, black pepper, cardamom, cumin, egg, eggplant, ghee, lamb, oil, olive oil, onion, parsley, pepper, potato, rice, salt, tomato, turmeric)
# [32/133] Mediterranean Lamb Chops  (labels: cloves, garlic, garlic powder, lamb, lemon, oil, olive oil, pepper, salt)
# [33/133] Roasted Eggplant Salad  (labels: cloves, cumin, egg, eggplant, garlic, lemon, oil, olive oil, parsley, pepper, pomegranate molasses, salt, tomato)
# [34/133] Slow-Roast Leg of Lamb  (labels: bay leaf, bell pepper, black pepper, cardamom, cinnamon, cloves, cumin, garlic, garlic powder, lamb, oil, olive oil, onion, onion powder, paprika, parsley, pepper, salt, tomato, tomato paste, turmeric)
# [35/133] Roasted Cauliflower Salad  (labels: cilantro, cloves, garlic, harissa, lemon, oil, olive oil, parsley, pepper, pomegranate molasses, salt, sumac, tahini, yogurt)
# [36/133] Za’atar stuffed French Toast  (labels: bread, butter, egg, milk, oil, olive oil, salt)
# [37/133] Aish El Saraya  (labels: bread, cream, water)
# [38/133] Arabic Salad  (labels: lemon, mint, oil, olive oil, onion, pomegranate molasses, salt, sumac, tomato)
# [39/133] Baked Spaghetti (Macarona Bi’Lahmeh)  (labels: beef, chili, garlic, garlic powder, pepper, salt, tomato, tomato paste, tomato sauce)
# [40/133] Baked Za’atar Chicken  (labels: chicken, lemon, oil, olive oil, onion, pepper, pomegranate molasses, potato, salt, sumac, zaatar)
# [41/133] Beef Shawarma  (labels: black pepper, bread, chili, cinnamon, cloves, coriander, cumin, garlic, garlic powder, lemon, oil, olive oil, onion, paprika, parsley, pepper, pita, rice, salt, sumac, tahini, tomato, turmeric, vinegar, water)
# [42/133] Freekeh with chicken  (labels: chicken, cinnamon, cumin, freekeh, garlic, garlic powder, lemon, oil, olive oil, onion, parsley, pepper, salt)
# [43/133] Hashweh (Spiced Rice & Meat)  (labels: allspice, beef, black pepper, cloves, garlic, oil, olive oil, onion, parsley, pepper, rice, salt, tomato, tomato paste)
# [44/133] Ma’amoul Coffee Cake  (labels: butter, cinnamon, cream, egg, oil, olive oil, salt, yogurt)
# [45/133] Mediterranean Freekeh Salad  (labels: bell pepper, cloves, freekeh, garlic, lemon, mint, oil, olive oil, onion, parsley, pepper, pomegranate molasses, salt, tomato, vinegar)
# [46/133] Mediterranean Style Potatoes  (labels: cloves, cream, garlic, lemon, oil, olive oil, paprika, pepper, potato, salt)
# [47/133] Middle Eastern Grilled Chicken  (labels: chicken, cinnamon, cloves, cumin, garlic, garlic powder, lemon, oil, olive oil, paprika, pepper, salt, sumac, tomato, tomato paste, vinegar, yogurt)
# [48/133] Muhammara  (labels: bell pepper, oil, olive oil, pepper, pomegranate molasses, salt, sumac, tomato, tomato paste)
# [49/133] Ouzi Rice  (labels: allspice, beef, cinnamon, garlic, garlic powder, ghee, oil, olive oil, pepper, rice, salt)
# [50/133] Qidreh  (labels: allspice, bay leaf, black pepper, cardamom, cinnamon, cloves, cumin, garlic, garlic powder, ghee, lamb, oil, olive oil, onion, pepper, rice, salt, turmeric, water)
# [51/133] Stuffed Eggplant Boats  (labels: allspice, beef, cloves, egg, eggplant, garlic, lemon, oil, olive oil, onion, parsley, pepper, salt, tahini, tomato, water, yogurt)
# [52/133] Tahini Salad  (labels: lemon, onion, parsley, pepper, salt, tahini, tomato, water)
# [53/133] Turkish Salad  (labels: bell pepper, cloves, garlic, harissa, lemon, mint, oil, olive oil, onion, parsley, pepper, pomegranate molasses, salt, sumac, tomato, tomato paste)
# [54/133] Zahra Bi’Laban  (labels: allspice, bay leaf, cardamom, cumin, garlic, lamb, oil, olive oil, onion, pepper, salt, yogurt)
# [55/133] Almond Cake  (labels: cream, egg, milk, oil, tahini, yogurt)
# [56/133] Arabic Rice  (labels: oil, olive oil, parsley, rice, salt, vermicelli, water)
# [57/133] Bechamel Pasta Bake  (labels: beef, butter, cloves, garlic, garlic powder, milk, nutmeg, oil, olive oil, onion, pepper, salt, tomato, tomato paste)
# [58/133] Beef Kofta Kebab  (labels: beef, bell pepper, chili, cloves, garlic, onion, parsley, pepper, salt, tomato, tomato paste)
# [59/133] Cheese Rolls  (labels: cream, egg, mint, paprika, pepper)
# [60/133] Chicken Makloubeh  (labels: bay leaf, cardamom, chicken, chili, garlic, garlic powder, ghee, lemon, oil, olive oil, onion, paprika, pepper, potato, rice, salt, tomato, tomato paste)
# Checkpoint saved at 60 recipes...
# [61/133] Date Nut Rolls  (labels: water)
# [62/133] Dawood Basha  (labels: beef, cloves, garlic, oil, olive oil, onion, parsley, pepper, pomegranate molasses, potato, salt, tomato, tomato paste)
# [63/133] Healthy Egg Salad  (labels: chili, cream, egg, labneh, oil, olive oil, pepper, salt, yogurt)
# [64/133] Knafeh Na’ameh  (labels: butter, ghee, milk, salt, turmeric, water)
# [65/133] Layali Lubnan (Semolina Milk Pudding)  (labels: cream, milk, water)
# [66/133] Creamy Lentil Soup  (labels: cloves, cumin, garlic, lemon, lentils, oil, olive oil, onion, pepper, pita, salt, turmeric, water)
# [67/133] Musakhan  (labels: bread, chicken, cumin, lemon, lime, oil, olive oil, onion, pepper, pita, salt, sumac, vinegar)
# [68/133] Sayadieh (Fish & Rice)  (labels: cumin, fish, garlic, lemon, oil, olive oil, onion, paprika, parsley, pepper, rice, salt, tahini, tomato, turmeric, water)
# [69/133] Spanakopita  (labels: butter, cloves, egg, garlic, milk, onion, parsley, pepper, salt, spinach, sumac)
# [70/133] Sticky Date Cake  (labels: butter, cinnamon, cream, egg, ginger, oil, salt, water)
# [71/133] Tomato Beef Saute  (labels: beef, cilantro, cloves, coriander, cumin, garlic, oil, onion, pepper, potato, rice, salt, tomato, tomato paste)
# [72/133] Za’atar Cake  (labels: egg, milk, oil, olive oil, salt)
# [73/133] Skipped: https://www.fufuskitchen.com/30-ramadan-recipes/
# [74/133] Arayes  (labels: beef, bread, chili, cloves, garlic, lamb, oil, olive oil, onion, paprika, parsley, pepper, pita, salt, tomato, tomato paste)
# [75/133] Creamy Chicken & Veggie Soup  (labels: butter, chicken, cloves, cream, garlic, garlic powder, lemon, milk, oil, olive oil, onion, paprika, pepper, potato, salt)
# [76/133] Falafel Sandwiches  (labels: bread, chili, cilantro, cloves, cumin, garlic, lemon, oil, onion, parsley, pita, salt, tahini, tomato, water)
# [77/133] Hareeseh Mahshi Bil Tamer (Semolina Cake stuffed with Dates)  (labels: butter, cinnamon, lemon, milk, salt, tahini, water)
# [78/133] Skipped: https://www.fufuskitchen.com/kousa-mashi-bil-laban-stuffed-zucchini-in-yogurt/
# [79/133] Mabrousheh  (labels: butter, egg, lemon, salt)
# [80/133] Malfoof (Stuffed Cabbage Leaves)  (labels: beef, cumin, garlic, lamb, oil, olive oil, onion, pepper, rice, salt, tomato, tomato paste, turmeric, water)
# [81/133] Mujadara (A Middle Eastern Rice & Lentil dish topped with caramelized onions)  (labels: cloves, cumin, garlic, lemon, lentils, mint, oil, olive oil, onion, pepper, rice, salt, tomato, tomato paste, water, yogurt)
# [82/133] Skipped: https://www.fufuskitchen.com/patlican-soslu-turkish-eggplant-tomato-dip/
# [83/133] Salatat Jarjeer (Middle Eastern Arugula Salad)  (labels: lemon, oil, olive oil, onion, pepper, salt, sumac)
# [84/133] Semolina cake with vermicelli  (labels: cream, egg, milk, oil)
# [85/133] Easy Dough  (labels: allspice, beef, chili, cinnamon, cloves, garlic, lamb, milk, oil, olive oil, onion, parsley, pepper, pomegranate molasses, salt, tomato, tomato paste, water)
# [86/133] Shish Barak  (labels: allspice, beef, cloves, garlic, lamb, milk, mint, oil, olive oil, onion, paprika, parsley, pepper, salt, water, yogurt)
# [87/133] Slow-Baked Boneless Beef Short Ribs  (labels: allspice, beef, chili, cumin, garlic, garlic powder, oil, olive oil, onion, onion powder, pepper, pomegranate molasses, salt)
# [88/133] Tahini Date Loaf  (labels: cinnamon, egg, milk, nutmeg, tahini)
# [89/133] Ghraybeh (Middle Eastern Shortbread Cookie)  (labels: butter, salt)
# [90/133] Turkish Chicken & Flatbread  (labels: bread, chicken, cilantro, cloves, garlic, ginger, lemon, lime, mint, oil, onion, parsley, pepper, salt, sumac, tomato, tomato paste, vinegar, yogurt)
# Checkpoint saved at 90 recipes...
# [91/133] Skipped: https://www.fufuskitchen.com/baked-turkey-kebabs/
# [92/133] Skipped: https://www.fufuskitchen.com/barazek-sesame-seed-cookies/
# [93/133] Skipped: https://www.fufuskitchen.com/batata-harra-spiced-potatoes/
# [94/133] Skipped: https://www.fufuskitchen.com/chicken-fatteh-fattet-jaj/
# [95/133] Skipped: https://www.fufuskitchen.com/cod-dinner/
# [96/133] Skipped: https://www.fufuskitchen.com/eggplant-fesenjan/
# [97/133] Skipped: https://www.fufuskitchen.com/fruit-cocktail-with-ashta/
# [98/133] Skipped: https://www.fufuskitchen.com/knafeh-with-nuts/
# [99/133] Skipped: https://www.fufuskitchen.com/makrouta/
# [100/133] Mansaf  (labels: bay leaf, bread, cardamom, ghee, lamb, lemon, oil, olive oil, onion, parsley, rice, salt, turmeric, water, yogurt)
# [101/133] Skipped: https://www.fufuskitchen.com/mediterranean-ground-beef-lettuce-taco/
# [102/133] Skipped: https://www.fufuskitchen.com/mediterranean-omelette/
# [103/133] Skipped: https://www.fufuskitchen.com/middle-eastern-baked-kufta/
# [104/133] Skipped: https://www.fufuskitchen.com/moroccan-lamb-stew/
# [105/133] No Bake Knafeh Cheesecake  (labels: butter, cinnamon, cream, salt, water)
# [106/133] Skipped: https://www.fufuskitchen.com/ouzi-spiced-rice-with-lamb/
# [107/133] Skipped: https://www.fufuskitchen.com/palestinian-zaatar-bread/
# [108/133] Skipped: https://www.fufuskitchen.com/pan-fried-nabulsi-cheese/
# [109/133] Skipped: https://www.fufuskitchen.com/anise-biscotti/
# [110/133] Skipped: https://www.fufuskitchen.com/atayef-middle-eastern-stuffed-pancake-dessert/
# [111/133] Skipped: https://www.fufuskitchen.com/baba-ghanoush-eggplant-dip/
# [112/133] Basbousa (Middle Eastern Semolina Cake)  (labels: butter, lemon, milk, salt, tahini, water, yogurt)
# [113/133] Skipped: https://www.fufuskitchen.com/cheese-spinach-and-zaatar-pies-mo3aganat/
# [114/133] Chicken Shawarma Bowl  (labels: black pepper, chicken, chili, cinnamon, cumin, garlic, garlic powder, lemon, mint, oil, olive oil, onion, paprika, pepper, potato, rice, salt, tahini, tomato, turmeric, water)
# [115/133] Chocolate Lazy Cake  (labels: milk)
# [116/133] Skipped: https://www.fufuskitchen.com/fattet-makdous-layered-baby-eggplant-dish/
# [117/133] Skipped: https://www.fufuskitchen.com/herb-olive-oil-potato-salad/
# [118/133] Skipped: https://www.fufuskitchen.com/hilbeh-fenugreek-seed-semolina-cake/
# [119/133] Skipped: https://www.fufuskitchen.com/kabseh-middle-eastern-rice-dish/
# [120/133] Skipped: https://www.fufuskitchen.com/khash-khash-cake/
# Checkpoint saved at 120 recipes...
# [121/133] Maamoul  (labels: butter, cinnamon, milk, salt, water)
# [122/133] Skipped: https://www.fufuskitchen.com/middle-eastern-garlic-sauce-toum/
# [123/133] Nescafe Cake  (labels: cream, milk, water)
# [124/133] Skipped: https://www.fufuskitchen.com/phyllo-meat-pies-egyptian-goulash/
# [125/133] Skipped: https://www.fufuskitchen.com/pistachio-ghoraybeh-thumbprint-cookies-middle-eastern-shortbread/
# [126/133] Vegetarian Stuffed Grape Leaves (Yalanji)  (labels: allspice, bell pepper, cardamom, chili, cloves, garlic, lemon, mint, oil, olive oil, onion, parsley, pepper, pomegranate molasses, rice, salt, tomato, tomato paste, water)
# [127/133] Skipped: https://www.fufuskitchen.com/chicken-veggie-curry-stew-comforting-nutritious-one-pot-dish/
# [128/133] Skipped: https://www.fufuskitchen.com/energy-date-balls/
# [129/133] Easy Authentic Hummus Recipe  (labels: cloves, cumin, garlic, lemon, oil, olive oil, parsley, salt, sumac, tahini)
# [130/133] Skipped: https://www.fufuskitchen.com/kanafeh-middle-eastern-cheese-dessert/
# [131/133] Skipped: https://www.fufuskitchen.com/oven-baked-spiced-tilapia-herb-tahini-sauce-tomato-salsa/
# [132/133] Skipped: https://www.fufuskitchen.com/shakshuka-middle-eastern-egg-tomato-dish/
# [133/133] Skipped: https://www.fufuskitchen.com/vegan-brownies/
# Done. Saved 96 recipes.
